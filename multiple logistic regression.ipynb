# %% [markdown]
# ### Importing the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Gobinath\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Importing data

# %%
loan_data = pd.read_json(r'C:\Users\Gobinath\Desktop\tasks\loan_data.json')

# %% [markdown]
# ### Data understanding

# %%
loan_data.shape
# Out:
# (511, 10)

# %%
loan_data.isna().sum()
# Out:
# Application_ID        0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# Credit_History        0
# Property_Area         0
# Income                0
# Application_Status    0
# dtype: int64

# %%
loan_data.dtypes
# Out:
# Application_ID        object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# Credit_History         int64
# Property_Area         object
# Income                object
# Application_Status    object
# dtype: object

# %% [markdown]
# ###  Data Preparation

# %%
loan_data.query('Dependents == "3+"')
# Out:
#     Application_ID  Gender Married Dependents     Education Self_Employed  \
# 7         LP001014    Male     Yes         3+      Graduate            No
# 27        LP001100    Male      No         3+      Graduate            No
# 53        LP001206    Male     Yes         3+      Graduate            No
# 60        LP001238    Male     Yes         3+  Not Graduate           Yes
# 65        LP001250    Male     Yes         3+  Not Graduate            No
# 66        LP001253    Male     Yes         3+      Graduate           Yes
# 70        LP001263    Male     Yes         3+      Graduate            No
# 94        LP001384    Male     Yes         3+  Not Graduate            No
# 112       LP001488    Male     Yes         3+      Graduate            No
# 132       LP001536    Male     Yes         3+      Graduate            No
# 145       LP001586    Male     Yes         3+  Not Graduate            No
# 150       LP001610    Male     Yes         3+      Graduate            No
# ...

# %%
loan_data['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+'], dtype=object)

# %%
loan_data_after_drop = loan_data.drop(['Application_ID'],axis=1)

# %%
loan_data_after_drop.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male      No          0      Graduate            No               1
# 1   Male     Yes          1      Graduate            No               1
# 2   Male     Yes          0      Graduate           Yes               1
# 3   Male     Yes          0  Not Graduate            No               1
# 4   Male      No          0      Graduate            No               1
#
#   Property_Area  Income Application_Status
# 0         Urban  medium                  Y
# 1         Rural  medium                  N
# 2         Urban     low                  Y
# 3         Urban     low                  Y
# 4         Urban  medium                  Y

# %%
loan_data_after_drop['Dependents'].replace(to_replace ='3+',value='3',inplace = True)

# %%
loan_data_after_drop.head(10)
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male      No          0      Graduate            No               1
# 1   Male     Yes          1      Graduate            No               1
# 2   Male     Yes          0      Graduate           Yes               1
# 3   Male     Yes          0  Not Graduate            No               1
# 4   Male      No          0      Graduate            No               1
# 5   Male     Yes          2      Graduate           Yes               1
# 6   Male     Yes          0  Not Graduate            No               1
# 7   Male     Yes          3      Graduate            No               0
# 8   Male     Yes          2      Graduate            No               1
# 9   Male     Yes          1      Graduate            No               1
#
#   Property_Area  Income Application_Status
# 0         Urban  medium                  Y
# 1         Rural  medium                  N
# 2         Urban     low                  Y
# ...
