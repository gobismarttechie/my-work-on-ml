# %%
import pandas as pd
ds = pd.read_csv(r"C:\Users\Gobinath\train.csv")
ds.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import pandas as pdd
df = pdd.read_csv(r"C:\Users\Gobinath\myFile0.csv")
df.head(10)
# Out:
#     id  firstname  lastname                        email  \
# 0  100     Romona     Carbo     Romona.Carbo@yopmail.com
# 1  101     Lauryn   Swigart   Lauryn.Swigart@yopmail.com
# 2  102   Georgina    Dahlia  Georgina.Dahlia@yopmail.com
# 3  103     Kalina     Beebe     Kalina.Beebe@yopmail.com
# 4  104        Sue    Alrich       Sue.Alrich@yopmail.com
# 5  105      Elsie  Ummersen   Elsie.Ummersen@yopmail.com
# 6  106     Lindie  Valoniah  Lindie.Valoniah@yopmail.com
# 7  107  Gavrielle      Bahr   Gavrielle.Bahr@yopmail.com
# 8  108     Elmira   Rosette   Elmira.Rosette@yopmail.com
# 9  109      Evita    Stover     Evita.Stover@yopmail.com
#
#                       email2      profession
# 0     Romona.Carbo@gmail.com  police officer
# 1   Lauryn.Swigart@gmail.com          doctor
# 2  Georgina.Dahlia@gmail.com       developer
# 3     Kalina.Beebe@gmail.com          worker
# 4       Sue.Alrich@gmail.com  police officer
# 5   Elsie.Ummersen@gmail.com  police officer
# ...

# %%
df.head(20)
# Out:
#      id   firstname    lastname                           email  \
# 0   100      Romona       Carbo        Romona.Carbo@yopmail.com
# 1   101      Lauryn     Swigart      Lauryn.Swigart@yopmail.com
# 2   102    Georgina      Dahlia     Georgina.Dahlia@yopmail.com
# 3   103      Kalina       Beebe        Kalina.Beebe@yopmail.com
# 4   104         Sue      Alrich          Sue.Alrich@yopmail.com
# 5   105       Elsie    Ummersen      Elsie.Ummersen@yopmail.com
# 6   106      Lindie    Valoniah     Lindie.Valoniah@yopmail.com
# 7   107   Gavrielle        Bahr      Gavrielle.Bahr@yopmail.com
# 8   108      Elmira     Rosette      Elmira.Rosette@yopmail.com
# 9   109       Evita      Stover        Evita.Stover@yopmail.com
# 10  110  Anestassia     Natalia  Anestassia.Natalia@yopmail.com
# 11  111       Randa       Merat         Randa.Merat@yopmail.com
# 12  112    Jessamyn        Nore       Jessamyn.Nore@yopmail.com
# 13  113     Therine  Anastatius  Therine.Anastatius@yopmail.com
# ...

# %%
df.head(50)
# Out:
#      id   firstname    lastname                           email  \
# 0   100      Romona       Carbo        Romona.Carbo@yopmail.com
# 1   101      Lauryn     Swigart      Lauryn.Swigart@yopmail.com
# 2   102    Georgina      Dahlia     Georgina.Dahlia@yopmail.com
# 3   103      Kalina       Beebe        Kalina.Beebe@yopmail.com
# 4   104         Sue      Alrich          Sue.Alrich@yopmail.com
# 5   105       Elsie    Ummersen      Elsie.Ummersen@yopmail.com
# 6   106      Lindie    Valoniah     Lindie.Valoniah@yopmail.com
# 7   107   Gavrielle        Bahr      Gavrielle.Bahr@yopmail.com
# 8   108      Elmira     Rosette      Elmira.Rosette@yopmail.com
# 9   109       Evita      Stover        Evita.Stover@yopmail.com
# 10  110  Anestassia     Natalia  Anestassia.Natalia@yopmail.com
# 11  111       Randa       Merat         Randa.Merat@yopmail.com
# 12  112    Jessamyn        Nore       Jessamyn.Nore@yopmail.com
# 13  113     Therine  Anastatius  Therine.Anastatius@yopmail.com
# ...

# %%
df["firstname"].dtype
# Out:
# dtype('O')

# %%
df["id"].dtype
# Out:
# dtype('int64')

# %%
df["email2"].dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# id             int64
# firstname     object
# lastname      object
# email         object
# email2        object
# profession    object
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'firstname', 'lastname', 'email', 'email2', 'profession'], dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=1000, step=1),
#  Index(['id', 'firstname', 'lastname', 'email', 'email2', 'profession'], dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 6000

# %%
df.shape
# Out:
# (1000, 6)

# %%
df.values
# Out:
# array([[100, 'Romona', 'Carbo', 'Romona.Carbo@yopmail.com',
#         'Romona.Carbo@gmail.com', 'police officer'],
#        [101, 'Lauryn', 'Swigart', 'Lauryn.Swigart@yopmail.com',
#         'Lauryn.Swigart@gmail.com', 'doctor'],
#        [102, 'Georgina', 'Dahlia', 'Georgina.Dahlia@yopmail.com',
#         'Georgina.Dahlia@gmail.com', 'developer'],
#        ...,
#        [1097, 'Carolina', 'Revkah', 'Carolina.Revkah@yopmail.com',
#         'Carolina.Revkah@gmail.com', 'police officer'],
#        [1098, 'Aimil', 'Weide', 'Aimil.Weide@yopmail.com',
#         'Aimil.Weide@gmail.com', 'firefighter'],
#        [1099, 'Netty', 'Allys', 'Netty.Allys@yopmail.com',
#         'Netty.Allys@gmail.com', 'police officer']], dtype=object)

# %%
#how many data this file has?
df.size
# Out:
# 6000

# %%
#the count of rows and columns
df.count
# Out:
# <bound method DataFrame.count of        id firstname lastname                        email  \
# 0     100    Romona    Carbo     Romona.Carbo@yopmail.com
# 1     101    Lauryn  Swigart   Lauryn.Swigart@yopmail.com
# 2     102  Georgina   Dahlia  Georgina.Dahlia@yopmail.com
# 3     103    Kalina    Beebe     Kalina.Beebe@yopmail.com
# 4     104       Sue   Alrich       Sue.Alrich@yopmail.com
# ..    ...       ...      ...                          ...
# 995  1095     Adele   Ardeha     Adele.Ardeha@yopmail.com
# 996  1096     Minne  Santoro    Minne.Santoro@yopmail.com
# 997  1097  Carolina   Revkah  Carolina.Revkah@yopmail.com
# 998  1098     Aimil    Weide      Aimil.Weide@yopmail.com
# 999  1099     Netty    Allys      Netty.Allys@yopmail.com
#
#                         email2      profession
# 0       Romona.Carbo@gmail.com  police officer
# 1     Lauryn.Swigart@gmail.com          doctor
# 2    Georgina.Dahlia@gmail.com       developer
# ...

# %%
#what are names of columns this file has?
df.columns
# Out:
# Index(['id', 'firstname', 'lastname', 'email', 'email2', 'profession'], dtype='object')

# %%
#what are the datatype of columns we have?
df.dtypes
# Out:
# id             int64
# firstname     object
# lastname      object
# email         object
# email2        object
# profession    object
# dtype: object

# %%
import pandas as pd
c = pd.read_csv(r"C:\Users\Gobinath\train.csv",index_col="PassengerId")
c.tail(10)
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 882                 0       3                        Markun, Mr. Johann
# 883                 0       3              Dahlberg, Miss. Gerda Ulrika
# 884                 0       2             Banfield, Mr. Frederick James
# 885                 0       3                    Sutehall, Mr. Henry Jr
# 886                 0       3      Rice, Mrs. William (Margaret Norton)
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 882            male  33.0      0      0            349257   7.8958   NaN
# ...

# %%
c.get_dtype_counts
# Out:
# <bound method NDFrame.get_dtype_counts of              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...

# %%
#generated descriptive details
c.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#calculating max value of all rows("for numbers only")
c.max()
# Out:
# Survived                              1
# Pclass                                3
# Name        van Melkebeke, Mr. Philemon
# Sex                                male
# Age                                  80
# SibSp                                 8
# Parch                                 6
# Ticket                        WE/P 5735
# Fare                            512.329
# dtype: object

# %%
#calculating min value of all rows("for numbers only")
c.min()
# Out:
# Survived                      0
# Pclass                        1
# Name        Abbing, Mr. Anthony
# Sex                      female
# Age                        0.42
# SibSp                         0
# Parch                         0
# Ticket                   110152
# Fare                          0
# dtype: object

# %%
c.mean()
# Out:
# Survived     0.383838
# Pclass       2.308642
# Age         29.699118
# SibSp        0.523008
# Parch        0.381594
# Fare        32.204208
# dtype: float64

# %%
c.median()
# Out:
# Survived     0.0000
# Pclass       3.0000
# Age         28.0000
# SibSp        0.0000
# Parch        0.0000
# Fare        14.4542
# dtype: float64

# %%
#2.standard deviation for all columns
c.std()
# Out:
# Survived     0.486592
# Pclass       0.836071
# Age         14.526497
# SibSp        1.102743
# Parch        0.806057
# Fare        49.693429
# dtype: float64

# %%
c.sample(10)
# Out:
#              Survived  Pclass                                       Name  \
# PassengerId
# 586                 1       1                        Taussig, Miss. Ruth
# 348                 1       3  Davison, Mrs. Thomas Henry (Mary E Finck)
# 543                 0       3          Andersson, Miss. Sigrid Elisabeth
# 628                 1       1              Longley, Miss. Gretchen Fiske
# 829                 1       3               McCormack, Mr. Thomas Joseph
# 789                 1       3                 Dean, Master. Bertram Vere
# 659                 0       2               Eitemiller, Mr. George Floyd
# 222                 0       2                       Bracken, Mr. James H
# 698                 1       3           Mullens, Miss. Katherine "Katie"
# 451                 0       2                      West, Mr. Edwy Arthur
#
#                 Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# PassengerId
# ...

# %%
c.head(50).mean()
# Out:
# Survived     0.440000
# Pclass       2.440000
# Age         27.472222
# SibSp        0.680000
# Parch        0.400000
# Fare        27.895416
# dtype: float64

# %%
c.tail(100).mean()
# Out:
# Survived     0.36000
# Pclass       2.34000
# Age         28.53869
# SibSp        0.60000
# Parch        0.44000
# Fare        24.76254
# dtype: float64

# %%
c['Age'].mean()
# Out:
# 29.69911764705882

# %%
#getting description for particular column
c['Pclass'].describe()
# Out:
# count    891.000000
# mean       2.308642
# std        0.836071
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        3.000000
# Name: Pclass, dtype: float64

# %%
#3.counting column wise
c['Name'].count()
# Out:
# 891

# %%
#4.avg of survived 
c['Survived'].mean()
# Out:
# 0.3838383838383838

# %%
c_gender = c.groupby(['Sex'])
c_gender.mean()
# Out:
#         Survived    Pclass        Age     SibSp     Parch       Fare
# Sex
# female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# male    0.188908  2.389948  30.726645  0.429809  0.235702  25.523893

# %%
c_survived = c.groupby(["Survived"])
c_survived.mean()
# Out:
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.950292  28.343690  0.473684  0.464912  48.395408

# %%
c.groupby('Sex')[["Survived"]].mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
c.groupby("Pclass")["Survived"].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
c.groupby('Age')[["Survived"]].median()
# Out:
#        Survived
# Age
# 0.42        1.0
# 0.67        1.0
# 0.75        1.0
# 0.83        1.0
# 0.92        1.0
# ...         ...
# 70.00       0.0
# 70.50       0.0
# 71.00       0.0
# 74.00       0.0
# 80.00       1.0
#
# [88 rows x 1 columns]

# %%
c.groupby(['Age'], sort=False)[['Survived']].mean()
# Out:
#        Survived
# Age
# 22.00  0.407407
# 38.00  0.454545
# 26.00  0.333333
# 35.00  0.611111
# 54.00  0.375000
# ...         ...
# 0.67   1.000000
# 30.50  0.000000
# 0.42   1.000000
# 34.50  0.000000
# 74.00  0.000000
#
# [88 rows x 1 columns]

# %%
#details of passengers who survived
c_survi = c [ c["Survived"] > 0]
print(c_survi)
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 9                   1       3
# 10                  1       2
# ...               ...     ...
# 876                 1       3
# 880                 1       1
# 881                 1       2
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# ...                                                        ...     ...   ...
# ...

# %%
#list of all male passengers
c_gend = c [c['Sex'] == 'male']
print(c_gend)
# Out:
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 1                   0       3         Braund, Mr. Owen Harris  male  22.0
# 5                   0       3        Allen, Mr. William Henry  male  35.0
# 6                   0       3                Moran, Mr. James  male   NaN
# 7                   0       1         McCarthy, Mr. Timothy J  male  54.0
# 8                   0       3  Palsson, Master. Gosta Leonard  male   2.0
# ...               ...     ...                             ...   ...   ...
# 884                 0       2   Banfield, Mr. Frederick James  male  28.0
# 885                 0       3          Sutehall, Mr. Henry Jr  male  25.0
# 887                 0       2           Montvila, Rev. Juozas  male  27.0
# 890                 1       1           Behr, Mr. Karl Howell  male  26.0
# 891                 0       3             Dooley, Mr. Patrick  male  32.0
#
# ...

# %%
#list of passengers age is equal to 25
c_sm = c [ c["Age"] == 25]
print(c_sm)
# Out:
#              Survived  Pclass  \
# PassengerId
# 76                  0       3
# 135                 0       2
# 247                 0       3
# 268                 1       3
# 272                 1       3
# 344                 0       2
# 354                 0       3
# 371                 1       1
# 443                 0       3
# 485                 1       1
# 499                 0       1
# 581                 1       2
# 667                 0       2
# 686                 0       2
# 694                 0       3
# 704                 0       3
# 729                 0       2
# 730                 0       3
# 785                 0       3
# 786                 0       3
# 795                 0       3
# 881                 1       2
# 885                 0       3
#
#                                                         Name     Sex   Age  \
# PassengerId
# 76                                   Moen, Mr. Sigurd Hansen    male  25.0
# ...

# %%
#displaying the column as series
c["Name"]
# Out:
# PassengerId
# 1                                Braund, Mr. Owen Harris
# 2      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                 Heikkinen, Miss. Laina
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                               Allen, Mr. William Henry
#                              ...
# 887                                Montvila, Rev. Juozas
# 888                         Graham, Miss. Margaret Edith
# 889             Johnston, Miss. Catherine Helen "Carrie"
# 890                                Behr, Mr. Karl Howell
# 891                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
#selecting the column name
c[["Name"]]
# Out:
#                                                           Name
# PassengerId
# 1                                      Braund, Mr. Owen Harris
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                       Heikkinen, Miss. Laina
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                     Allen, Mr. William Henry
# ...                                                        ...
# 887                                      Montvila, Rev. Juozas
# 888                               Graham, Miss. Margaret Edith
# 889                   Johnston, Miss. Catherine Helen "Carrie"
# 890                                      Behr, Mr. Karl Howell
# 891                                        Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %%
#selecting the first element
c.iloc[0]
# Out:
# Survived                          0
# Pclass                            3
# Name        Braund, Mr. Owen Harris
# Sex                            male
# Age                              22
# SibSp                             1
# Parch                             0
# Ticket                    A/5 21171
# Fare                           7.25
# Cabin                           NaN
# Embarked                          S
# Name: 1, dtype: object

# %%
#selecting 882th element from last
c.iloc[-882]
# Out:
# Survived                                      1
# Pclass                                        2
# Name        Nasser, Mrs. Nicholas (Adele Achem)
# Sex                                      female
# Age                                          14
# SibSp                                         1
# Parch                                         0
# Ticket                                   237736
# Fare                                    30.0708
# Cabin                                       NaN
# Embarked                                      C
# Name: 10, dtype: object

# %%
#selecting the first row
c.iloc[0:1]
# Out:
#              Survived  Pclass                     Name   Sex   Age  SibSp  \
# PassengerId
# 1                   0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#              Parch     Ticket  Fare Cabin Embarked
# PassengerId
# 1                0  A/5 21171  7.25   NaN        S

# %%
#selecting upto third row
c.iloc[:3]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
#selecting only the third row
c.iloc[2:3]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
#select the column third from last
c.iloc[:,-3]
# Out:
# PassengerId
# 1       7.2500
# 2      71.2833
# 3       7.9250
# 4      53.1000
# 5       8.0500
#         ...
# 887    13.0000
# 888    30.0000
# 889    23.4500
# 890    30.0000
# 891     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
#selcting the second column
c.iloc[:,2]
# Out:
# PassengerId
# 1                                Braund, Mr. Owen Harris
# 2      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                 Heikkinen, Miss. Laina
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                               Allen, Mr. William Henry
#                              ...
# 887                                Montvila, Rev. Juozas
# 888                         Graham, Miss. Margaret Edith
# 889             Johnston, Miss. Catherine Helen "Carrie"
# 890                                Behr, Mr. Karl Howell
# 891                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
#selecting particular row elements and column elements
c.iloc[[33],[6,7]]
# Out:
#              Parch      Ticket
# PassengerId
# 34               0  C.A. 24579

# %%
c.iloc[[33,99,100],[6,7]]
# Out:
#              Parch      Ticket
# PassengerId
# 34               0  C.A. 24579
# 100              0      244367
# 101              0      349245

# %%
c.iloc[[],[4,5]]
# Out:
# Empty DataFrame
# Columns: [Age, SibSp]
# Index: []

# %%
import pandas  as pd
d = pd.read_csv(r"C:\Users\Gobinath\myFile0.csv")
print (d)
# Out:
#        id firstname lastname                        email  \
# 0     100    Romona    Carbo     Romona.Carbo@yopmail.com
# 1     101    Lauryn  Swigart   Lauryn.Swigart@yopmail.com
# 2     102  Georgina   Dahlia  Georgina.Dahlia@yopmail.com
# 3     103    Kalina    Beebe     Kalina.Beebe@yopmail.com
# 4     104       Sue   Alrich       Sue.Alrich@yopmail.com
# ..    ...       ...      ...                          ...
# 995  1095     Adele   Ardeha     Adele.Ardeha@yopmail.com
# 996  1096     Minne  Santoro    Minne.Santoro@yopmail.com
# 997  1097  Carolina   Revkah  Carolina.Revkah@yopmail.com
# 998  1098     Aimil    Weide      Aimil.Weide@yopmail.com
# 999  1099     Netty    Allys      Netty.Allys@yopmail.com
#
#                         email2      profession
# 0       Romona.Carbo@gmail.com  police officer
# 1     Lauryn.Swigart@gmail.com          doctor
# 2    Georgina.Dahlia@gmail.com       developer
# 3       Kalina.Beebe@gmail.com          worker
# ...

# %%
#people who are doctor
d_pol = d[d["profession"]=="doctor"]
print(d_pol)
# Out:
#        id firstname  lastname                         email  \
# 1     101    Lauryn   Swigart    Lauryn.Swigart@yopmail.com
# 12    112  Jessamyn      Nore     Jessamyn.Nore@yopmail.com
# 15    115    Emilia      Olin       Emilia.Olin@yopmail.com
# 16    116    Daphne     Raama      Daphne.Raama@yopmail.com
# 27    127    Ariela   Weinreb    Ariela.Weinreb@yopmail.com
# ..    ...       ...       ...                           ...
# 971  1071   Belinda  Brackely  Belinda.Brackely@yopmail.com
# 978  1078   Paulita     Ricki     Paulita.Ricki@yopmail.com
# 980  1080     Adore    Loring      Adore.Loring@yopmail.com
# 986  1086    Almeta      Clie       Almeta.Clie@yopmail.com
# 996  1096     Minne   Santoro     Minne.Santoro@yopmail.com
#
#                          email2 profession
# 1      Lauryn.Swigart@gmail.com     doctor
# 12      Jessamyn.Nore@gmail.com     doctor
# 15        Emilia.Olin@gmail.com     doctor
# 16       Daphne.Raama@gmail.com     doctor
# ...

# %%
#people who are workers
d_doc = d[d["profession"]=="worker"]
print(d_doc)
# Out:
#        id  firstname    lastname                           email  \
# 3     103     Kalina       Beebe        Kalina.Beebe@yopmail.com
# 7     107  Gavrielle        Bahr      Gavrielle.Bahr@yopmail.com
# 8     108     Elmira     Rosette      Elmira.Rosette@yopmail.com
# 13    113    Therine  Anastatius  Therine.Anastatius@yopmail.com
# 23    123  Elbertina       Grobe     Elbertina.Grobe@yopmail.com
# ..    ...        ...         ...                             ...
# 983  1083      Elora   Laurianne     Elora.Laurianne@yopmail.com
# 985  1085     Elvira      Vastah       Elvira.Vastah@yopmail.com
# 988  1088    Gwyneth      Alejoa      Gwyneth.Alejoa@yopmail.com
# 993  1093  Georgetta       Plato     Georgetta.Plato@yopmail.com
# 995  1095      Adele      Ardeha        Adele.Ardeha@yopmail.com
#
#                            email2 profession
# 3          Kalina.Beebe@gmail.com     worker
# 7        Gavrielle.Bahr@gmail.com     worker
# 8        Elmira.Rosette@gmail.com     worker
# ...

# %%
c[["Age"]].agg(["min","max","var","std","sem","skew","kurt"])
# Out:
#              Age
# min     0.420000
# max    80.000000
# var   211.019125
# std    14.526497
# sem     0.543640
# skew    0.389108
# kurt    0.178274

# %%
c[["Age"]].agg(["median","mean"])
# Out:
#               Age
# median  28.000000
# mean    29.699118

# %%
c[["Age"]].agg(["mode"])
# Out:
#     Age
#    mode
# 0  24.0
