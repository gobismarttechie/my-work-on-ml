# %%
import pandas as pd

# %%
house_data = pd.read_csv(r"C:\Users\Gobinath\Desktop\tasks\Chennai houseing sale.csv")

# %%
house_data.head()
# Out:
#    PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0  P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1  P09411  Anna Nagar      1986  19-12-2006             26        2.0
# 2  P01812       Adyar       909  04-02-2012             70        1.0
# 3  P05346   Velachery      1855  13-03-2010             14        3.0
# 4  P06210  Karapakkam      1226  05-10-2009             84        1.0
#
#    N_BATHROOM  N_ROOM SALE_COND PARK_FACIL  ... UTILITY_AVAIL  STREET MZZONE  \
# 0         1.0       3  AbNormal        Yes  ...        AllPub   Paved      A
# 1         1.0       5  AbNormal         No  ...        AllPub  Gravel     RH
# 2         1.0       3  AbNormal        Yes  ...           ELO  Gravel     RL
# 3         2.0       5    Family         No  ...       NoSewr    Paved      I
# 4         1.0       3  AbNormal        Yes  ...        AllPub  Gravel      C
#
#   QS_ROOMS QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  COMMIS  SALES_PRICE
# ...

# %%
house_data.shape
# Out:
# (7109, 22)

# %%
pd.set_option('display.max_columns', None)

# %%
house_data['AREA'].unique()
# Out:
# array(['Karapakkam', 'Anna Nagar', 'Adyar', 'Velachery', 'Chrompet',
#        'KK Nagar', 'TNagar', 'T Nagar', 'Chrompt', 'Chrmpet', 'Karapakam',
#        'Ana Nagar', 'Chormpet', 'Adyr', 'Velchery', 'Ann Nagar',
#        'KKNagar'], dtype=object)

# %%
house_data['UTILITY_AVAIL'].unique()
# Out:
# array(['AllPub', 'ELO', 'NoSewr ', 'NoSeWa', 'All Pub'], dtype=object)

# %%
house_data.replace({'UTILITY_AVAIL':{'NoSewr ':'NoSewr',
                             }},inplace=True)

# %%
house_data.replace({'STREET':{'Pavd':'Paved',
                              'NoAccess':'No Access'
                             }},inplace=True)

# %%
house_data.query('UTILITY_AVAIL == "NoSeWa"')
# Out:
#       PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 5     P00219    Chrompet      1220  11-09-2014             36        2.0
# 29    P00755     T Nagar      1806  18-08-2013            138        2.0
# 31    P02696       Adyar       868  15-08-2011             15        1.0
# 34    P05950  Anna Nagar      1709  22-11-2009            130        1.0
# 35    P05051    KK Nagar      2114  09-05-2010             46        3.0
# ...      ...         ...       ...         ...            ...        ...
# 7100  P05438     T Nagar      1733  24-02-2010            191        1.0
# 7102  P05560  Karapakkam       701  03-02-2010            100        1.0
# 7103  P05133  Karapakkam      1462  23-04-2010             68        2.0
# 7105  P10000   Velachery      1897  08-04-2004             52        3.0
# 7106  P09594   Velachery      1614  25-08-2006            152        2.0
#
#       N_BATHROOM  N_ROOM    SALE_COND PARK_FACIL  DATE_BUILD   BUILDTYPE  \
# ...

# %%
house_data.replace({'AREA':{'Velchery':'Velachery'
                             }},inplace=True)

# %%
pd.set_option('display.max_rows',100)

# %%
house_data
# Out:
#       PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0     P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1     P09411  Anna Nagar      1986  19-12-2006             26        2.0
# 2     P01812       Adyar       909  04-02-2012             70        1.0
# 3     P05346   Velachery      1855  13-03-2010             14        3.0
# 4     P06210  Karapakkam      1226  05-10-2009             84        1.0
# ...      ...         ...       ...         ...            ...        ...
# 7104  P03834  Karapakkam       598  03-01-2011             51        1.0
# 7105  P10000   Velachery      1897  08-04-2004             52        3.0
# 7106  P09594   Velachery      1614  25-08-2006            152        2.0
# 7107  P06508  Karapakkam       787  03-08-2009             40        1.0
# 7108  P09794   Velachery      1896  13-07-2005            156        3.0
#
#       N_BATHROOM  N_ROOM    SALE_COND PARK_FACIL  DATE_BUILD   BUILDTYPE  \
# ...

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7109 entries, 0 to 7108
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PRT_ID         7109 non-null   object
#  1   AREA           7109 non-null   object
#  2   INT_SQFT       7109 non-null   int64
#  3   DATE_SALE      7109 non-null   object
#  4   DIST_MAINROAD  7109 non-null   int64
#  5   N_BEDROOM      7108 non-null   float64
#  6   N_BATHROOM     7104 non-null   float64
#  7   N_ROOM         7109 non-null   int64
#  8   SALE_COND      7109 non-null   object
#  9   PARK_FACIL     7109 non-null   object
#  10  DATE_BUILD     7109 non-null   object
#  11  BUILDTYPE      7109 non-null   object
#  12  UTILITY_AVAIL  7109 non-null   object
#  13  STREET         7109 non-null   object
#  14  MZZONE         7109 non-null   object
#  15  QS_ROOMS       7109 non-null   float64
#  16  QS_BATHROOM    7109 non-null   float64
# ...

# %%
house_data.shape
# Out:
# (7109, 22)

# %%
house_data.head(10)
# Out:
#    PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0  P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1  P09411  Anna Nagar      1986  19-12-2006             26        2.0
# 2  P01812       Adyar       909  04-02-2012             70        1.0
# 3  P05346   Velachery      1855  13-03-2010             14        3.0
# 4  P06210  Karapakkam      1226  05-10-2009             84        1.0
# 5  P00219    Chrompet      1220  11-09-2014             36        2.0
# 6  P09105    Chrompet      1167  05-04-2007            137        1.0
# 7  P09679   Velachery      1847  13-03-2006            176        3.0
# 8  P03377    Chrompet       771  06-04-2011            175        1.0
# 9  P09623   Velachery      1635  22-06-2006             74        2.0
#
#    N_BATHROOM  N_ROOM SALE_COND PARK_FACIL  DATE_BUILD   BUILDTYPE  \
# 0         1.0       3  AbNormal        Yes  15-05-1967  Commercial
# ...

# %%
house_data.tail(10)
# Out:
#       PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 7099  P03828       Adyar       895  05-01-2011            197        1.0
# 7100  P05438     T Nagar      1733  24-02-2010            191        1.0
# 7101  P05042  Karapakkam       666  11-05-2010             51        1.0
# 7102  P05560  Karapakkam       701  03-02-2010            100        1.0
# 7103  P05133  Karapakkam      1462  23-04-2010             68        2.0
# 7104  P03834  Karapakkam       598  03-01-2011             51        1.0
# 7105  P10000   Velachery      1897  08-04-2004             52        3.0
# 7106  P09594   Velachery      1614  25-08-2006            152        2.0
# 7107  P06508  Karapakkam       787  03-08-2009             40        1.0
# 7108  P09794   Velachery      1896  13-07-2005            156        3.0
#
#       N_BATHROOM  N_ROOM    SALE_COND PARK_FACIL  DATE_BUILD   BUILDTYPE  \
# 7099         1.0       3      AdjLand        Yes  15-01-1971       House
# ...

# %%
house_data['AREA'].dtype
# Out:
# dtype('O')

# %%
house_data.isnull().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DATE_SALE         0
# DIST_MAINROAD     0
# N_BEDROOM         1
# N_BATHROOM        5
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# DATE_BUILD        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# REG_FEE           0
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %%
house_data.isna()
# Out:
#       PRT_ID   AREA  INT_SQFT  DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0      False  False     False      False          False      False
# 1      False  False     False      False          False      False
# 2      False  False     False      False          False      False
# 3      False  False     False      False          False      False
# 4      False  False     False      False          False      False
# ...      ...    ...       ...        ...            ...        ...
# 7104   False  False     False      False          False      False
# 7105   False  False     False      False          False      False
# 7106   False  False     False      False          False      False
# 7107   False  False     False      False          False      False
# 7108   False  False     False      False          False      False
#
#       N_BATHROOM  N_ROOM  SALE_COND  PARK_FACIL  DATE_BUILD  BUILDTYPE  \
# 0          False   False      False       False       False      False
# ...

# %%
house_data
# Out:
#       PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0     P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1     P09411  Anna Nagar      1986  19-12-2006             26        2.0
# 2     P01812       Adyar       909  04-02-2012             70        1.0
# 3     P05346   Velachery      1855  13-03-2010             14        3.0
# 4     P06210  Karapakkam      1226  05-10-2009             84        1.0
# ...      ...         ...       ...         ...            ...        ...
# 7104  P03834  Karapakkam       598  03-01-2011             51        1.0
# 7105  P10000   Velachery      1897  08-04-2004             52        3.0
# 7106  P09594   Velachery      1614  25-08-2006            152        2.0
# 7107  P06508  Karapakkam       787  03-08-2009             40        1.0
# 7108  P09794   Velachery      1896  13-07-2005            156        3.0
#
#       N_BATHROOM  N_ROOM    SALE_COND PARK_FACIL  DATE_BUILD   BUILDTYPE  \
# ...

# %%
house_data.dropna()
# Out:
#       PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0     P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1     P09411  Anna Nagar      1986  19-12-2006             26        2.0
# 2     P01812       Adyar       909  04-02-2012             70        1.0
# 3     P05346   Velachery      1855  13-03-2010             14        3.0
# 4     P06210  Karapakkam      1226  05-10-2009             84        1.0
# ...      ...         ...       ...         ...            ...        ...
# 7104  P03834  Karapakkam       598  03-01-2011             51        1.0
# 7105  P10000   Velachery      1897  08-04-2004             52        3.0
# 7106  P09594   Velachery      1614  25-08-2006            152        2.0
# 7107  P06508  Karapakkam       787  03-08-2009             40        1.0
# 7108  P09794   Velachery      1896  13-07-2005            156        3.0
#
#       N_BATHROOM  N_ROOM    SALE_COND PARK_FACIL  DATE_BUILD   BUILDTYPE  \
# ...

# %%
house_data.query('AREA=="Karapakkam" & N_ROOM > 3')
# Out:
#       PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 16    P06039  Karapakkam      1639  04-11-2009            175        2.0
# 48    P04106  Karapakkam      1412  06-11-2010             28        2.0
# 58    P02088  Karapakkam      1469  12-12-2011            200        2.0
# 61    P03221  Karapakkam      1691  02-05-2011            100        2.0
# 76    P01725  Karapakkam      1378  19-02-2012            192        2.0
# ...      ...         ...       ...         ...            ...        ...
# 6991  P04099  Karapakkam      1419  08-11-2010            115        2.0
# 6992  P04763  Karapakkam      1395  03-07-2010             77        2.0
# 7075  P02906  Karapakkam      1496  01-07-2011            144        2.0
# 7088  P05164  Karapakkam      1696  16-04-2010             48        2.0
# 7103  P05133  Karapakkam      1462  23-04-2010             68        2.0
#
#       N_BATHROOM  N_ROOM    SALE_COND PARK_FACIL  DATE_BUILD   BUILDTYPE  \
# ...

# %%
house_data['AREA'].unique()
# Out:
# array(['Karapakkam', 'Anna Nagar', 'Adyar', 'Velachery', 'Chrompet',
#        'KK Nagar', 'TNagar', 'T Nagar', 'Chrompt', 'Chrmpet', 'Karapakam',
#        'Ana Nagar', 'Chormpet', 'Adyr', 'Ann Nagar', 'KKNagar'],
#       dtype=object)

# %%
house_data['SALE_COND'].unique()
# Out:
# array(['AbNormal', 'Family', 'Partial', 'AdjLand', 'Normal Sale',
#        'Ab Normal', 'Partiall', 'Adj Land', 'PartiaLl'], dtype=object)

# %%
house_data['UTILITY_AVAIL'].unique()
# Out:
# array(['AllPub', 'ELO', 'NoSewr', 'NoSeWa', 'All Pub'], dtype=object)

# %%
house_data['STREET'].unique()
# Out:
# array(['Paved', 'Gravel', 'No Access'], dtype=object)

# %%
house_data['MZZONE'].unique()
# Out:
# array(['A', 'RH', 'RL', 'I', 'C', 'RM'], dtype=object)

# %%
house_data['MZZONE'].nunique()
# Out:
# 6

# %%
house_data.nunique()
# Out:
# PRT_ID           7109
# AREA               16
# INT_SQFT         1699
# DATE_SALE        2798
# DIST_MAINROAD     201
# N_BEDROOM           4
# N_BATHROOM          2
# N_ROOM              5
# SALE_COND           9
# PARK_FACIL          3
# DATE_BUILD       5808
# BUILDTYPE           5
# UTILITY_AVAIL       5
# STREET              3
# MZZONE              6
# QS_ROOMS           31
# QS_BATHROOM        31
# QS_BEDROOM         31
# QS_OVERALL        479
# REG_FEE          7038
# COMMIS           7011
# SALES_PRICE      7057
# dtype: int64

# %%
house_data_group = house_data.groupby(by='STREET')

# %%
house_data_group = house_data.groupby(['AREA','STREET'])

# %%
print(house_data_group)

# %%
house_data.iloc[2:-1,:-1]
# Out:
#       PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 2     P01812       Adyar       909  04-02-2012             70        1.0
# 3     P05346   Velachery      1855  13-03-2010             14        3.0
# 4     P06210  Karapakkam      1226  05-10-2009             84        1.0
# 5     P00219    Chrompet      1220  11-09-2014             36        2.0
# 6     P09105    Chrompet      1167  05-04-2007            137        1.0
# ...      ...         ...       ...         ...            ...        ...
# 7103  P05133  Karapakkam      1462  23-04-2010             68        2.0
# 7104  P03834  Karapakkam       598  03-01-2011             51        1.0
# 7105  P10000   Velachery      1897  08-04-2004             52        3.0
# 7106  P09594   Velachery      1614  25-08-2006            152        2.0
# 7107  P06508  Karapakkam       787  03-08-2009             40        1.0
#
#       N_BATHROOM  N_ROOM    SALE_COND PARK_FACIL  DATE_BUILD   BUILDTYPE  \
# ...

# %%
sales_data17 = pd.read_csv(r"C:\Users\Gobinath\Downloads\Sales Transactions-2017.csv")

# %%
sales_data18 = pd.read_csv(r"C:\Users\Gobinath\Downloads\Sales Transactions-2018.csv")

# %%
sales_data19 = pd.read_csv(r"C:\Users\Gobinath\Downloads\Sales Transactions-2019.csv")

# %%
sales_data_1718 = pd.concat([sales_data17,sales_data18],ignore_index = True)

# %%
sales_data_1718
# Out:
#              Date   Voucher               Party            Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 92025  31/03/2019  Sal:9610         HAMPI FOODS        SPOON SOOFY
# 92026         NaN       NaN                 NaN                NaN
# 92027         NaN       NaN                 NaN                NaN
# 92028         NaN   Total                   NaN                NaN
# 92029         NaN   Total                   NaN                NaN
#
#                 Qty           Rate           Gross        Disc  Voucher Amount
# 0                 2       1,690.00        3,380.00         NaN       13,100.00
# ...

# %%
data_1718 = sales_data17.append(sales_data18,ignore_index = True)

# %%
data_171819 = data_1718.append(sales_data19,ignore_index=True)

# %%
data_171819
# Out:
#               Date   Voucher               Party            Product  \
# 0         1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1         1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2         1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3         1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4         1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...            ...       ...                 ...                ...
# 111201  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 111202         NaN       NaN                 NaN                NaN
# 111203         NaN       NaN                 NaN                NaN
# 111204         NaN   Total                   NaN                NaN
# 111205         NaN   Total                   NaN                NaN
#
#                  Qty          Rate          Gross        Disc Voucher Amount
# ...

# %%
data_merge = sales_data18.merge(sales_data19,how='right')

# %%
data_merge2 = sales_data18.merge(sales_data19,how='right')
# Out:
#             Date  Voucher            Party         Product           Qty  \
# 0       1/4/2019  Sal:687  BALAJI PLASTICS   DONA-VAI-9100             1
# 1       1/4/2019  Sal:687  BALAJI PLASTICS  SMART BOUL(48)             1
# 2       1/4/2019  Sal:688  BALAJI PLASTICS      Vishnu Ice           110
# 3                                     28/3                             0
# 4       1/4/2019  Sal:689  BALAJI PLASTICS     100LEAF -SP             3
# ...          ...      ...              ...             ...           ...
# 279956       NaN      NaN              NaN             NaN           NaN
# 279957       NaN      NaN              NaN             NaN           NaN
# 279958       NaN      NaN              NaN             NaN           NaN
# 279959       NaN  Total                NaN             NaN     99,284.90
# 279960       NaN  Total                NaN             NaN  2,710,193.00
#
#                 Rate          Gross        Disc Voucher Amount
# ...
